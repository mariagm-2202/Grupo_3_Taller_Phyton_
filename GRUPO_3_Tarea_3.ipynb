# %% [markdown]
# I. Utilizando 𝒔𝒄𝒊𝒑𝒚. 𝒔𝒕𝒂𝒕𝒔, crea un programa que modele la probabilidad de obtener un
# número específico de éxitos en una serie de lanzamientos de una moneda sin trucos
# (probabilidad de éxito 𝒑 = 𝟎. 𝟓). Genera la probabilidad de obtener exactamente 7 caras
# en 10 lanzamientos

# %%
# ejercicio I
from scipy.stats import binom, norm

# %%
#probabilidad= binom.pmf(k,n, p)
n=10 # de lanzamientos
p=0.5 #prob. de exito(cara)
k=7 #Numero especifico de exitos(cara)
binom.pmf(7, 10, 0.5)
# Out:
# 0.11718749999999999

# %% [markdown]
# II. Calcula la probabilidad acumulada de obtener 7 o menos caras en 10 lanzamientos

# %%
# Ejercicio II
import matplotlib.pyplot as plt
prob_moneda = binom.cdf(7, 10, 0.5)
print(f'Respuesta: La probabilidad de obtener 7 o menos caras en 10 lanzamientos es de {prob_moneda:.4f}.')
# Out:
# Respuesta: La probabilidad de obtener 7 o menos caras en 10 lanzamientos es de 0.9453.

# %% [markdown]
# III. Grafica la distribución binomial completa para los 10 lanzamientos, mostrando la probabilidad de obtener desde 0 hasta 10 caras.

# %%
import numpy as np
k= np.arange(n+1)
probabilidades= binom.pmf(k, 10, 0.5)
plt.bar(k, probabilidades, color='skyblue', alpha=0.8)
plt.xlabel('Número de caras')
plt.ylabel('Probabilidad')
plt.title('Distribución Binomial de 10 lanzamientos de una moneda sin trucos')

plt.grid(axis='y')
plt.show()

# %% [markdown]
# IV.Ahora la moneda tiene mayor probabilidad de caer en cara (probabilidad de éxito 𝒑 =
# 𝟎. 𝟖). ¿Cómo cambian los resultados? Vuelve a realizar los ejercicios I, II y III.

# %%
mayor_prob_cara = binom.rvs(1, 0.8, size=10)

mayor_prob_cara
# Out:
# array([0, 0, 0, 0, 1, 1, 1, 0, 1, 0])

# %%
# I)
prob_moneda = binom.pmf(7, 10, 0.8)

print(f'Respuesta: La probabilidad de obtener 7 caras en 10 lanzamientos con la probabilidad alterada es de {prob_moneda:.4f}.')
# Out:
# Respuesta: La probabilidad de obtener 7 caras en 10 lanzamientos con la probabilidad alterada es de 0.2013.

# %%
# II)
prob_moneda = binom.cdf(7, 10, 0.8)

print(f'Respuesta: La probabilidad de obtener 7 o menos caras en 10 lanzamientos con la probabilidad alterada es de {prob_moneda:.4f}.')
# Out:
# Respuesta: La probabilidad de obtener 7 o menos caras en 10 lanzamientos con la probabilidad alterada es de 0.3222.

# %%
import numpy as np
k= np.arange(n+1)
probabilidades= binom.pmf(k, 10, 0.8)
plt.bar(k, probabilidades, color='skyblue', alpha=0.8)
plt.xlabel('Número de caras')
plt.ylabel('Probabilidad')
plt.title('Distribución Binomial de 10 lanzamientos de una moneda sin trucos')

plt.grid(axis='y')
plt.show()

# %% [markdown]
# V. Utilizando 𝒔𝒄𝒊𝒑𝒚. 𝒔𝒕𝒂𝒕𝒔, realiza un análisis de una distribución normal con una media de
# 0 y desviación estándar de 1. Genera un conjunto de datos aleatorios con 1000
# muestras a partir de esta distribución.

# %%
# V. Análisis de distribución normal (media=0, desviación estándar=1)
mean = 0
std_dev = 1
data_normal = np.random.normal(mean, std_dev, 1000)

# %% [markdown]
# VI. Calcula y muestra la media, la desviación estándar y la mediana de los datos
# generados

# %%
# VI. Cálculo de estadísticos de los datos generados
mean_data = np.mean(data_normal)
std_dev_data = np.std(data_normal)
median_data = np.median(data_normal)

print(f"Media de los datos generados: {mean_data}")
print(f"Desviación estándar de los datos generados: {std_dev_data}")
print(f"Mediana de los datos generados: {median_data}")
# Out:
# Media de los datos generados: 0.048965870382102844
# Desviación estándar de los datos generados: 1.0102512954552845
# Mediana de los datos generados: 0.07128845362579184

# %% [markdown]
# VII. Grafica el histograma de los datos y superpón la curva de la distribución normal
# teórica.

# %%
# VII. Gráfico del histograma y la curva de distribución normal teórica
plt.figure(figsize=(10, 6))
plt.hist(data_normal, bins=30, density=True, alpha=0.6, color='g', label='Datos generados')

xmin, xmax = plt.xlim()
x_norm = np.linspace(xmin, xmax, 100)
p_norm = norm.pdf(x_norm, mean, std_dev)

plt.plot(x_norm, p_norm, 'k', linewidth=2, label='Distribución Normal Teórica')
plt.title('Histograma y Curva de Distribución Normal')
plt.xlabel('Valor')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.show()

# %% [markdown]
# VIII.Calcula la probabilidad de que un valor caiga dentro del rango de -1 a 1 (una desviación
# estándar de la media).

# %%
prob = norm.cdf(1, 0, 1) - norm.cdf(-1, 0, 1)

print(f"La probabilidad de que un valor caiga entre -1 y 1 es: {prob:.4f}.")
# Out:
# La probabilidad de que un valor caiga entre -1 y 1 es: 0.6827.
